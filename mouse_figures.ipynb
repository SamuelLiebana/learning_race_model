# %%
import numpy as np
from mouse_fitting_functions import fitMice, loadMouseWeights
from mouse_plotting_functions import plotWeightTrajectories, plotBehavMouseVsModel, simulateMouse, sessionAlignedAcc

# %%
#fitMice('DAP013', iteration=0) # this only has to be run once and saves a npy file with the learnt weights

# %%
fit_9 = loadMouseWeights('DAP011', iteration=0)
print(np.log2(fit_9['hyp']['sigma']))
print(np.log2(fit_9['hyp']['sigDay']))
print(fit_9['logEvd'])
print(fit_9['duration'])
# Out:
# [-1.78716685 -8.52401238 -6.09410204 -6.39165119 -7.67535409]
# [ 0.97844665 -6.47664803 -2.57495732 -2.97368912 -9.22758039]
# -6853.181233105555
# 0:14:25.930530

# %%
weight_traj = plotWeightTrajectories(fit_9)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
sim_9 = simulateMouse(fit_9, 10, 'random')
sim_9_same = simulateMouse(fit_9, 10, 'same')

# %%
plotBehavMouseVsModel(fit_9, sim_9, ['psy_rt_acc_sessions'], figsize=(15, 5))
# Out:
# /home/neurotheory/samuel/dopaminepl/code/empirical_bayes_race_model/mouse_plotting_functions.py:511: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, axs1 = plt.subplots(1, 3, sharex=True, sharey=False)

# %%
plotBehavMouseVsModel(fit_9, sim_9, ['psy_rt_acc_quartiles'], figsize=(5,10))

# %%
plotBehavMouseVsModel(fit_9, sim_9_same, ['accuracy_vs_sessions']) # make sure here you feed sim with 'same'

# %%
plotBehavMouseVsModel(fit_9, sim_9_same, ['accuracy_vs_quartiles'])

# %%
plotBehavMouseVsModel(fit_9, sim_9, ['all_psy_rt_acc_quartiles'])

# %%
plotBehavMouseVsModel(fit_9, sim_9_same, ['rt_vs_quartiles'])

# %%
plotBehavMouseVsModel(fit_9, sim_9_same, ['rt_vs_sessions'])

# %%
sessionAlignedAcc(fit_9, sim_9_same)

# %%
from statsmodels.stats.proportion import proportion_confint

print(proportion_confint(1, 104, method='binom_test', alpha=0.05))
