# %%
import numpy as np
from mouse_fitting_functions import fitMice, loadMouseWeights
from mouse_plotting_functions import plotWeightTrajectories
from population_plotting_functions import plotAverageWeightTrajectories, plotAvgBehavMiceVsModel, plotAvgWeightQuartiles, sessionAlignedAccAcrossMice

# %%
all_mice = ['DAP007', 'DAP009', 'DAP011','DAP013', 'DAP014', 'DAP015', 'DAP017', 
           'DAP019', 'DAP022', 'DAP023', 'DAP024', 'DAP027', 'DAP028', 'DAP031', 'DAP033', 'DAP035', 'DAP037']


#fitMice(all_mice)

# %%
plotAverageWeightTrajectories(all_mice, save=True)

# %%
plotAvgBehavMiceVsModel(all_mice, ['psy_quartiles'], 10)

# %%
plotAvgBehavMiceVsModel(all_mice, ['acc_quartiles'], 10)

# %%
plotAvgBehavMiceVsModel(all_mice, ['rt_quartiles'], 10)

# %%
plotAvgWeightQuartiles(all_mice)
# Out:
# /home/neurotheory/anaconda3/envs/jax_sam/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/neurotheory/anaconda3/envs/jax_sam/lib/python3.7/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in long_scalars
#   ret = ret / rcount
# /home/neurotheory/anaconda3/envs/jax_sam/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/neurotheory/anaconda3/envs/jax_sam/lib/python3.7/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in long_scalars
#   ret = ret / rcount
# /home/neurotheory/anaconda3/envs/jax_sam/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...

# %%
sessionAlignedAccAcrossMice(all_mice, 10)
